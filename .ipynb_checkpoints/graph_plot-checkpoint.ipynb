# %%
import pickle as pkl
import matplotlib.pyplot as plt
import os
import numpy as np
import pandas as pd

# %%
plt.figure(figsize=(12, 12))

plt.rc('axes', titlesize=18) # fontsize of the axes title 
plt.rc('axes', labelsize=18) # fontsize of the x and y labels 
plt.rc('xtick', labelsize=15) # fontsize of the tick labels 
plt.rc('ytick', labelsize=15) # fontsize of the tick labels 
plt.rc('legend', fontsize=14) # legend fontsize 

plt.title('Last updated accuracy by prefix length')
plt.ylabel('Accuracy')
plt.xlabel('Prefix length')
plt.xticks(rotation='45')
axes = plt.gca()
axes.set_ylim([0.4, 1.05])

with open('./result/off_dt_acc.pkl' ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'-*',color='green',linewidth=4, linestyle='--',label = 'OFF DT',markersize=10)

with open('./result/off_rf_acc.pkl' ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'-*',color='purple',linewidth=4, linestyle='--',label = 'OFF RF',markersize=10)


with open('./result/efdt_lastacc.pkl' ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'-o',color='red',linewidth=4, label = 'EFDT',markersize=10)

with open('./result/hatc_lastacc.pkl' ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'-o',color='blue',linewidth=4, label = 'HATC',markersize=10)
with open('./result/htc_lastacc.pkl' ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'-o',color='orange',linewidth=4, label = 'HTC',markersize=10)

plt.legend()
plt.tight_layout()
# plt.savefig('./img/online last_acc_streaming.png')
plt.savefig('./img/last_acc_streaming.png')

# %%
plt.figure(figsize=(12, 12))

plt.rc('axes', titlesize=18) # fontsize of the axes title 
plt.rc('axes', labelsize=18) # fontsize of the x and y labels 
plt.rc('xtick', labelsize=15) # fontsize of the tick labels 
plt.rc('ytick', labelsize=15) # fontsize of the tick labels 
plt.rc('legend', fontsize=14) # legend fontsize 

plt.title('Last updated accuracy by prefix length')
plt.ylabel('Accuracy')
plt.xlabel('Prefix length')
plt.xticks(rotation='45')
axes = plt.gca()
axes.set_ylim([0.4, 1.05])
with open('./result/off_dt_acc.pkl' ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'s',linewidth=4, color='green',linestyle='--',label = 'OFF DT',markersize=10)

with open('./result/off_rf_acc.pkl' ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'-*',linewidth=4, color='purple',linestyle='--',label = 'OFF RF',markersize=10)

with open('./result/noneg_off_dt_acc.pkl' ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'s',linewidth=4, color='#0047ab',linestyle=':',label = 'No neg OFF DT',markersize=10)

with open('./result/noneg_off_rf_acc.pkl' ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'-*',linewidth=4,color='#b24662', linestyle=':',label = 'No neg OFF RF',markersize=10)


plt.legend()
plt.tight_layout()
plt.savefig('./img/offline acc_streaming.png')

# %%
proportion = {7: {True: 0, False: 219},
8: {True: 0, False: 240},
10: {True: 0, False: 24},
11: {True: 179, False: 117},
12: {True: 26, False: 124},
13: {True: 0, False: 2},
14: {True: 26, False: 21},
15: {True: 3, False: 12},
17: {True: 3, False: 4}}

keylist = sorted(proportion.keys())
Truenumber = [proportion[x][True] for x in keylist]
Falsenumber = [proportion[x][False] for x in keylist]
bar_width = 0.35
import pandas as pd

pro2 = {}
for t in sorted(proportion.keys()):
    pro2[t] =  proportion[t]
df = pd.DataFrame.from_dict(pro2).T
print(df)
plt.cla()
plt.clf()
plt.figure(figsize=(15, 15))
df.plot(kind='bar', rot=0)
plt.title('Cases label appeared by prefix length', fontsize=20)
plt.legend(fontsize='12')
plt.tight_layout()
plt.savefig('./img/class proportion.png')
# Out:
#     True   False
# 7       0    219
# 8       0    240
# 10      0     24
# 11    179    117
# 12     26    124
# 13      0      2
# 14     26     21
# 15      3     12
# 17      3      4

# %%
# Experiment settings
dataset_label = 'bpic17_streaming'
bin_n = 50

try:
    os.makedirs('./img/%s'%(dataset_label))
except:
    pass

# %%
plt.figure(figsize=(12, 8))

plt.rc('axes', titlesize=18) # fontsize of the axes title 
plt.rc('axes', labelsize=18) # fontsize of the x and y labels 
plt.rc('xtick', labelsize=15) # fontsize of the tick labels 
plt.rc('ytick', labelsize=15) # fontsize of the tick labels 
plt.rc('legend', fontsize=14) # legend fontsize 

plt.title('Continuous evaluation accuracy by prefix length')
plt.ylabel('Accuracy')
plt.xlabel('Prefix length')
# plt.xticks(rotation='45')
axes = plt.gca()
# axes.set_ylim([0.3, 1.05])


with open('./result/%s/htc_continuous_evaluation_plbin.pkl'%(dataset_label) ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'s',linewidth=4, color='green',linestyle='--',label = 'HTC',markersize=10)

with open('./result/%s/hatc_continuous_evaluation_plbin.pkl'%(dataset_label) ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'-*',linewidth=4, color='purple',linestyle='--',label = 'HATC',markersize=10)

with open('./result/%s/efdt_continuous_evaluation_plbin.pkl'%(dataset_label) ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'o',linewidth=4, color='#0047ab',linestyle=':',label = 'EFDT',markersize=10)


plt.legend()
plt.tight_layout()
plt.savefig('./img/%s/continuous_evaluation_acc_plbin.pdf'%(dataset_label))

# %%
# Experiment settings
dataset_label = 'bpic15'
bin_n = 50

try:
    os.makedirs('./img/%s'%(dataset_label))
except:
    pass
plt.figure(figsize=(16, 8))

plt.rc('axes', titlesize=18) # fontsize of the axes title 
plt.rc('axes', labelsize=18) # fontsize of the x and y labels 
plt.rc('xtick', labelsize=15) # fontsize of the tick labels 
plt.rc('ytick', labelsize=15) # fontsize of the tick labels 
plt.rc('legend', fontsize=14) # legend fontsize 

fig, axarr = plt.subplots(2, 2, figsize=(16,8))
fig.suptitle('BPIC 2015_1 Continuous evaluation accuracy by progress',fontsize=20)
plt.subplot(121)
plt.ylabel('Accuracy')
plt.xlabel('Progress (%)')
axes = plt.gca()
# axes.set_ylim([0.50, 0.9])
with open('./result/%s/htc_continuous_evaluation_rt%sbin.pkl'%(dataset_label,bin_n) ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'s',linewidth=4, color='green',linestyle='--',label = 'HTC',markersize=5)

with open('./result/%s/hatc_continuous_evaluation_rt%sbin.pkl'%(dataset_label,bin_n) ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'-*',linewidth=4, color='purple',linestyle='-',label = 'HATC',markersize=5)

with open('./result/%s/efdt_continuous_evaluation_rt%sbin.pkl'%(dataset_label,bin_n) ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'o',linewidth=4, color='#0047ab',linestyle=':',label = 'EFDT',markersize=5)

xtick_label = ['%s'%((int(t)-1)*2) if (int(t)-1)*2 % 10 ==0 else ' ' for t in data[0]]
plt.xticks(ticks=data[0],labels=xtick_label)
plt.legend()

plt.subplot(222)
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False
)

# plt.title('EFDT Continuous evaluation accuracy by progress')
with open('./result/%s/efdt_continuous_evaluation_rt%sbin.pkl'%(dataset_label,bin_n) ,'rb') as f:
    data = pkl.load(f)
    

plt.plot(data[0],data[1],'o',linewidth=4, color='#0047ab',linestyle=':',label = 'EFDT',markersize=5)
plt.legend(loc='center right')
plt.subplot(224)
# plt.title('EFDT Continuous evaluation accuracy by progress')

plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False
)

with open('./result/%s/htc_continuous_evaluation_rt%sbin.pkl'%(dataset_label,bin_n) ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'s',linewidth=4, color='green',linestyle='--',label = 'HTC',markersize=5)

with open('./result/%s/hatc_continuous_evaluation_rt%sbin.pkl'%(dataset_label,bin_n) ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'-*',linewidth=4, color='purple',linestyle='-',label = 'HATC',markersize=3)

plt.legend()
plt.tight_layout()

plt.savefig('./img/%s/continuous_evaluation_acc_rt50bin.pdf'%(dataset_label))

# %%
plt.figure(figsize=(16, 8))
window_size=50
plt.rc('axes', titlesize=18) # fontsize of the axes title 
plt.rc('axes', labelsize=18) # fontsize of the x and y labels 
plt.rc('xtick', labelsize=15) # fontsize of the tick labels 
plt.rc('ytick', labelsize=15) # fontsize of the tick labels 
plt.rc('legend', fontsize=14) # legend fontsize 


# dataset = 'artificial_concept_mixed'
for classifier in ['htc','hatc','efdt']:
    name = '%s %s window %s.pkl'%(dataset_label,classifier, window_size)
    with open('./result/%s/%s'%(dataset_label,name) ,'rb') as f:
        data =pkl.load(f)
    print(dataset_label)
    print(len(data))
    plt.plot(data,label = classifier)
plt.title('BPIC17 Window(%s)-evaluation average accuracy'%(window_size))
plt.legend()
plt.ylabel('Accuracy')
plt.xlabel('Finished cases')

import numpy as np
with open('./result/%s/off_rf_acc.pkl'%(dataset_label),'rb') as f:
    rfdata = pkl.load(f)
with open('./result/%s/off_dt_acc.pkl'%(dataset_label),'rb') as f:
    dtdata = pkl.load(f)
plt.axhline(y=np.mean(rfdata[1]), color='purple', linestyle='-',label='Offline RF')
plt.axhline(y=np.mean(dtdata[1]), color='darkblue', linestyle='-',label='Offline DT')
# plt.axvline(x=393, color='black', linestyle=':',label='Concept drift in window')
# plt.text(395,1.0,'393',fontsize=14)
plt.legend()
plt.tight_layout()
# dataset = 'artificial_concept'
# plt.savefig('./img/%s/window_evaluation average acc.png'%(dataset_label))
# Out:
# bpic17_streaming
# 1183
# bpic17_streaming
# 1183
# bpic17_streaming
# 1183

# %%
# Experiment settings
dataset_list = ['bpic15','bpic17_streaming','artificial_concept_Index-base']
dataset_label = 'bpic15'
bin_n = 50

try:
    os.makedirs('./img/%s'%(dataset_label))
except:
    pass


plt.figure(figsize=(12, 24))

plt.rc('axes', titlesize=18) # fontsize of the axes title 
plt.rc('axes', labelsize=18) # fontsize of the x and y labels 
plt.rc('xtick', labelsize=15) # fontsize of the tick labels 
plt.rc('ytick', labelsize=15) # fontsize of the tick labels 
plt.rc('legend', fontsize=14) # legend fontsize 

plt.subplot(311)
plt.title('BPIC 2015_1 Continuous evaluation accuracy by prefix length')
plt.ylabel('Accuracy')
plt.xlabel('Prefix length')
# plt.xticks(rotation='45')
axes = plt.gca()
axes.set_ylim([-0.05, 1.05])


with open('./result/%s/htc_continuous_evaluation_plbin.pkl'%(dataset_label) ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'s',linewidth=4, color='green',linestyle='--',label = 'HTC',markersize=10)

with open('./result/%s/hatc_continuous_evaluation_plbin.pkl'%(dataset_label) ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'-*',linewidth=4, color='purple',linestyle='--',label = 'HATC',markersize=10)

with open('./result/%s/efdt_continuous_evaluation_plbin.pkl'%(dataset_label) ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'o',linewidth=4, color='#0047ab',linestyle=':',label = 'EFDT',markersize=10)
plt.legend()

dataset_label = 'bpic17_streaming'
bin_n = 50

try:
    os.makedirs('./img/%s'%(dataset_label))
except:
    pass

plt.subplot(312)
plt.title('BPIC 2017 Continuous evaluation accuracy by prefix length')
plt.ylabel('Accuracy')
plt.xlabel('Prefix length')
# plt.xticks(rotation='45')
axes = plt.gca()
axes.set_ylim([-0.05, 1.05])


with open('./result/%s/htc_continuous_evaluation_plbin.pkl'%(dataset_label) ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'s',linewidth=4, color='green',linestyle='--',label = 'HTC',markersize=10)

with open('./result/%s/hatc_continuous_evaluation_plbin.pkl'%(dataset_label) ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'-*',linewidth=4, color='purple',linestyle='--',label = 'HATC',markersize=10)

with open('./result/%s/efdt_continuous_evaluation_plbin.pkl'%(dataset_label) ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'o',linewidth=4, color='#0047ab',linestyle=':',label = 'EFDT',markersize=10)
plt.legend(loc='upper left')

dataset_label = 'artificial_concept_Index-base'
bin_n = 50

try:
    os.makedirs('./img/%s'%(dataset_label))
except:
    pass

plt.subplot(313)
plt.title('IRO5K Continuous evaluation accuracy by prefix length')
plt.ylabel('Accuracy')
plt.xlabel('Prefix length')
# plt.xticks(rotation='45')
axes = plt.gca()
axes.set_ylim([-0.05, 1.05])


with open('./result/%s/htc_continuous_evaluation_plbin.pkl'%(dataset_label) ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'s',linewidth=4, color='green',linestyle='--',label = 'HTC',markersize=10)

with open('./result/%s/hatc_continuous_evaluation_plbin.pkl'%(dataset_label) ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'-*',linewidth=4, color='purple',linestyle='--',label = 'HATC',markersize=10)

with open('./result/%s/efdt_continuous_evaluation_plbin.pkl'%(dataset_label) ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'o',linewidth=4, color='#0047ab',linestyle=':',label = 'EFDT',markersize=10)

plt.legend(loc='upper left')
plt.tight_layout()
plt.savefig('./img/continuous_evaluation_acc_plbin.pdf')

# %%
# Experiment settings
# dataset_label = 'bpic15'
# bin_n = 50

# try:
#     os.makedirs('./img/%s'%(dataset_label))
# except:
#     pass
# plt.figure(figsize=(16, 36))
# plt.rc('axes', titlesize=18) # fontsize of the axes title 
# plt.rc('axes', labelsize=18) # fontsize of the x and y labels 
# plt.rc('xtick', labelsize=15) # fontsize of the tick labels 
# plt.rc('ytick', labelsize=15) # fontsize of the tick labels 
# plt.rc('legend', fontsize=14) # legend fontsize 

# plt.subplot(411)
# plt.title('BPIC 2015_1 Continuous evaluation accuracy by progress')
# plt.ylabel('Accuracy')
# plt.xlabel('Progress (%)')
# plt.tight_layout()
# axes = plt.gca()
# axes.set_ylim([0.40, 0.8])
# with open('./result/%s/htc_continuous_evaluation_rt%sbin.pkl'%(dataset_label,bin_n) ,'rb') as f:
#     data = pkl.load(f)
# plt.plot(data[0],data[1],'s',linewidth=4, color='green',linestyle='--',label = 'HTC',markersize=5)

# with open('./result/%s/hatc_continuous_evaluation_rt%sbin.pkl'%(dataset_label,bin_n) ,'rb') as f:
#     data = pkl.load(f)
# plt.plot(data[0],data[1],'-*',linewidth=4, color='purple',linestyle='-',label = 'HATC',markersize=5)

# with open('./result/%s/efdt_continuous_evaluation_rt%sbin.pkl'%(dataset_label,bin_n) ,'rb') as f:
#     data = pkl.load(f)
# plt.plot(data[0],data[1],'o',linewidth=4, color='#0047ab',linestyle=':',label = 'EFDT',markersize=5)

# xtick_label = ['%s'%((int(t)-1)*2) if (int(t)-1)*2 % 10 ==0 else ' ' for t in data[0]]
# plt.xticks(ticks=data[0],labels=xtick_label)
# plt.legend()
# plt.tight_layout()

# plt.subplot(423)
# plt.tick_params(
#     axis='x',          # changes apply to the x-axis
#     which='both',      # both major and minor ticks are affected
#     bottom=False,      # ticks along the bottom edge are off
#     top=False,         # ticks along the top edge are off
#     labelbottom=False
# )

# # plt.title('EFDT Continuous evaluation accuracy by progress')
# with open('./result/%s/efdt_continuous_evaluation_rt%sbin.pkl'%(dataset_label,bin_n) ,'rb') as f:
#     data = pkl.load(f)
    

# plt.plot(data[0],data[1],'o',linewidth=4, color='#0047ab',linestyle=':',label = 'EFDT',markersize=5)
# plt.tight_layout()
# plt.legend(loc='center right')

# plt.subplot(424)
# # plt.title('EFDT Continuous evaluation accuracy by progress')

# plt.tick_params(
#     axis='x',          # changes apply to the x-axis
#     which='both',      # both major and minor ticks are affected
#     bottom=False,      # ticks along the bottom edge are off
#     top=False,         # ticks along the top edge are off
#     labelbottom=False
# )

# with open('./result/%s/htc_continuous_evaluation_rt%sbin.pkl'%(dataset_label,bin_n) ,'rb') as f:
#     data = pkl.load(f)
# plt.plot(data[0],data[1],'s',linewidth=4, color='green',linestyle='--',label = 'HTC',markersize=5)

# with open('./result/%s/hatc_continuous_evaluation_rt%sbin.pkl'%(dataset_label,bin_n) ,'rb') as f:
#     data = pkl.load(f)
# plt.plot(data[0],data[1],'-*',linewidth=4, color='purple',linestyle='-',label = 'HATC',markersize=3)
# plt.legend()
# plt.tight_layout()

dataset_list = ['bpic15','bpic17_streaming','artificial_concept_Index-base']
dataset_label = 'bpic17_streaming'
bin_n = 50
plt.figure(figsize=(16, 20))

try:
    os.makedirs('./img/%s'%(dataset_label))
except:
    pass
axes.set_ylim([0.40, 0.8])

plt.subplot(211)
plt.title('BPIC 2017 Continuous evaluation accuracy by progress')
plt.ylabel('Accuracy')
plt.xlabel('Progress (%)')
axes = plt.gca()
axes.set_ylim([0.40, 0.8])
with open('./result/%s/htc_continuous_evaluation_rt%sbin.pkl'%(dataset_label,bin_n) ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'s',linewidth=4, color='green',linestyle='--',label = 'HTC',markersize=5)

with open('./result/%s/hatc_continuous_evaluation_rt%sbin.pkl'%(dataset_label,bin_n) ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'-*',linewidth=4, color='purple',linestyle='-',label = 'HATC',markersize=5)

with open('./result/%s/efdt_continuous_evaluation_rt%sbin.pkl'%(dataset_label,bin_n) ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'o',linewidth=4, color='#0047ab',linestyle=':',label = 'EFDT',markersize=5)
plt.tight_layout()

xtick_label = ['%s'%((int(t)-1)*2) if (int(t)-1)*2 % 10 ==0 else ' ' for t in data[0]]
plt.xticks(ticks=data[0],labels=xtick_label)
plt.legend(loc='lower right')

dataset_label = 'artificial_concept_Index-base'
bin_n = 50

try:
    os.makedirs('./img/%s'%(dataset_label))
except:
    pass

plt.subplot(212)

plt.title('IRO5K Continuous evaluation accuracy by progress')
plt.ylabel('Accuracy')
plt.xlabel('Progress (%)')
axes = plt.gca()
with open('./result/%s/htc_continuous_evaluation_rt%sbin.pkl'%(dataset_label,bin_n) ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'s',linewidth=4, color='green',linestyle='--',label = 'HTC',markersize=5)

with open('./result/%s/hatc_continuous_evaluation_rt%sbin.pkl'%(dataset_label,bin_n) ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'-*',linewidth=4, color='purple',linestyle='-',label = 'HATC',markersize=5)

with open('./result/%s/efdt_continuous_evaluation_rt%sbin.pkl'%(dataset_label,bin_n) ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'o',linewidth=4, color='#0047ab',linestyle=':',label = 'EFDT',markersize=5)

xtick_label = ['%s'%((int(t)-1)*2) if (int(t)-1)*2 % 10 ==0 else ' ' for t in data[0]]
plt.xticks(ticks=data[0],labels=xtick_label)
plt.legend(loc='lower right')
plt.tight_layout()
# plt.show()
plt.savefig('./img/continuous_evaluation_acc_rtbin.pdf')

# %%
dataset_list = ['bpic15','bpic17_streaming','artificial_concept_Index-base']
dataset_label = 'bpic15'
bin_n = 50
plt.figure(figsize=(16, 27))

window_size=50
plt.rc('axes', titlesize=18) # fontsize of the axes title 
plt.rc('axes', labelsize=18) # fontsize of the x and y labels 
plt.rc('xtick', labelsize=15) # fontsize of the tick labels 
plt.rc('ytick', labelsize=15) # fontsize of the tick labels 
plt.rc('legend', fontsize=14) # legend fontsize 
plt.subplot(311)

# dataset = 'artificial_concept_mixed'
for classifier in ['htc','hatc','efdt']:
    name = '%s %s window %s.pkl'%(dataset_label,classifier, window_size)
    with open('./result/%s/%s'%(dataset_label,name) ,'rb') as f:
        data =pkl.load(f)
    plt.plot(data,label = classifier)
plt.title('BPIC 2015_1 Window(%s)-evaluation average accuracy'%(window_size), fontsize=24)
plt.legend()
plt.ylabel('Accuracy')
plt.xlabel('Finished cases')

with open('./result/%s/off_rf_acc.pkl'%(dataset_label),'rb') as f:
    rfdata = pkl.load(f)
with open('./result/%s/off_dt_acc.pkl'%(dataset_label),'rb') as f:
    dtdata = pkl.load(f)
plt.axhline(y=np.mean(rfdata[1]), color='purple', linestyle='-',label='Offline RF')
plt.axhline(y=np.mean(dtdata[1]), color='darkblue', linestyle='-',label='Offline DT')
# plt.axvline(x=393, color='black', linestyle=':',label='Concept drift in window')
# plt.text(395,1.0,'393',fontsize=14)
plt.legend()
plt.tight_layout()

dataset_list = ['bpic15','bpic17_streaming','artificial_concept_Index-base']
dataset_label = 'bpic17_streaming'
bin_n = 50
plt.subplot(312)


# dataset = 'artificial_concept_mixed'
for classifier in ['htc','hatc','efdt']:
    name = '%s %s window %s.pkl'%(dataset_label,classifier, window_size)
    with open('./result/%s/%s'%(dataset_label,name) ,'rb') as f:
        data =pkl.load(f)
    plt.plot(data,label = classifier)
plt.title('BPIC 2017 Window(%s)-evaluation average accuracy'%(window_size), fontsize=24)
plt.legend()
plt.ylabel('Accuracy')
plt.xlabel('Finished cases')

with open('./result/%s/off_rf_acc.pkl'%(dataset_label),'rb') as f:
    rfdata = pkl.load(f)
with open('./result/%s/off_dt_acc.pkl'%(dataset_label),'rb') as f:
    dtdata = pkl.load(f)
plt.axhline(y=np.mean(rfdata[1]), color='purple', linestyle='-',label='Offline RF')
plt.axhline(y=np.mean(dtdata[1]), color='darkblue', linestyle='-',label='Offline DT')
plt.tight_layout()

dataset_list = ['bpic15','bpic17_streaming','artificial_concept_Index-base']
dataset_label = 'artificial_concept_Index-base'
bin_n = 50
plt.subplot(313)


# dataset = 'artificial_concept_mixed'
for classifier in ['htc','hatc','efdt']:
    name = '%s %s window %s.pkl'%(dataset_label,classifier, window_size)
    with open('./result/%s/%s'%(dataset_label,name) ,'rb') as f:
        data =pkl.load(f)
    plt.plot(data,label = classifier)
plt.title('IRO5K Window(%s)-evaluation average accuracy'%(window_size), fontsize=24)
plt.legend()
plt.ylabel('Accuracy')
plt.xlabel('Finished cases')

with open('./result/%s/off_rf_acc.pkl'%(dataset_label),'rb') as f:
    rfdata = pkl.load(f)
with open('./result/%s/off_dt_acc.pkl'%(dataset_label),'rb') as f:
    dtdata = pkl.load(f)
plt.axhline(y=np.mean(rfdata[1]), color='purple', linestyle='-',label='Offline RF')
plt.axhline(y=np.mean(dtdata[1]), color='darkblue', linestyle='-',label='Offline DT')

plt.axvline(x=293, color='black', linestyle=':',label='Concept drift in window')
plt.text(295,0.95,'293',fontsize=14)
plt.legend()
plt.tight_layout()
# plt.savefig('./img/window_evaluation average acc.pdf')

# %%
import pandas as pd
case_duration= {2: {True: 49, False: 2}, 3: {True: 24, False: 2}, 4: {True: 26, False: 4}, 5: {True: 22, False: 9}, 6: {True: 25, False: 10}, 7: {True: 13, False: 0}, 8: {True: 34, False: 5}, 9: {True: 80, False: 3}, 10: {True: 15, False: 12}, 11: {True: 3, False: 11}, 12: {True: 0, False: 7}, 13: {True: 2, False: 7}, 14: {True: 0, False: 1}, 15: {True: 0, False: 6}, 16: {True: 1, False: 8}, 17: {True: 0, False: 10}, 18: {True: 2, False: 4}, 19: {True: 1, False: 5}, 20: {True: 3, False: 8}, 21: {True: 0, False: 6}, 22: {True: 0, False: 5}, 23: {True: 0, False: 4}, 24: {True: 1, False: 3}, 25: {True: 1, False: 6}, 26: {True: 0, False: 4}, 27: {True: 0, False: 3}, 28: {True: 0, False: 2}, 29: {True: 0, False: 4}, 30: {True: 0, False: 1}, 31: {True: 0, False: 5}, 32: {True: 1, False: 2}, 33: {True: 0, False: 1}, 34: {True: 0, False: 15}, 35: {True: 0, False: 23}, 36: {True: 0, False: 14}, 37: {True: 0, False: 37}, 38: {True: 0, False: 17}, 39: {True: 0, False: 64}, 40: {True: 0, False: 25}, 41: {True: 0, False: 40}, 42: {True: 0, False: 17}, 43: {True: 0, False: 39}, 44: {True: 0, False: 31}}
df = pd.DataFrame.from_dict(case_duration).T
plt.figure(figsize=(16, 8))
bar_width =0.4
# for c in list(df.columns.values):
plt.bar(df.index.values, list(df[True]), bar_width,label = True)
plt.bar(df.index.values+0.5, list(df[False]), bar_width, label=False)
# plt.title('BPIC 2015_1')
plt.ylabel('Frequency')
plt.xlabel('Prefix length')
plt.xticks(np.arange(2, 45, 1.0))
plt.legend()
plt.tight_layout()
plt.savefig('./img/bpic15_case length.pdf')

# %%
case_duration= {2: {True: 0, False: 0}, 3: {True: 1, False: 4}, 4: {True: 2, False: 9}, 5: {True: 1, False: 7}, 6: {True: 5, False: 11}, 7: {True: 3, False: 16}, 8: {True: 6, False: 23}, 9: {True: 19, False: 37}, 10: {True: 13, False: 419}, 11: {True: 15, False: 552}, 12: {True: 290, False: 121}, 13: {True: 221, False: 19}, 14: {True: 0, False: 83}}
df = pd.DataFrame.from_dict(case_duration).T
plt.figure(figsize=(16, 8))
bar_width =0.4
# for c in list(df.columns.values):
plt.bar(df.index.values, list(df[True]), bar_width,label = True)
plt.bar(df.index.values+0.5, list(df[False]), bar_width, label=False)
# plt.title('BPIC 2017')
plt.ylabel('Frequency')
plt.xlabel('Prefix length')
plt.xticks(np.arange(2, 15, 1.0))
plt.legend()
plt.tight_layout()
plt.savefig('./img/bpic17_case length.pdf')

# %%
case_duration={2: {True: 0, False: 0}, 3: {True: 0, False: 0}, 4: {True: 0, False: 0}, 5: {True: 0, False: 0}, 6: {True: 0, False: 219}, 7: {True: 0, False: 240}, 8: {True: 0, False: 0}, 9: {True: 0, False: 24}, 10: {True: 179, False: 117}, 11: {True: 26, False: 124}}

df = pd.DataFrame.from_dict(case_duration).T
plt.figure(figsize=(16, 8))
bar_width =0.4
# for c in list(df.columns.values):
plt.bar(df.index.values, list(df[True]), bar_width,label = True)
plt.bar(df.index.values+0.5, list(df[False]), bar_width, label=False)
plt.title('IRO5K')
plt.ylabel('Frequency')
plt.xlabel('Prefix length')
plt.xticks(np.arange(2, 12, 1.0))
plt.legend()
plt.tight_layout()
plt.savefig('./img/iro5k_case length.pdf')

# %%
# Experiment settings
dataset_list = ['bpic15','bpic17_streaming','artificial_concept_Index-base']
dataset_label = 'bpic15'
bin_n = 50

try:
    os.makedirs('./img/%s'%(dataset_label))
except:
    pass


plt.figure(figsize=(16, 20))

plt.rc('axes', titlesize=18) # fontsize of the axes title 
plt.rc('axes', labelsize=18) # fontsize of the x and y labels 
plt.rc('xtick', labelsize=15) # fontsize of the tick labels 
plt.rc('ytick', labelsize=15) # fontsize of the tick labels 
plt.rc('legend', fontsize=14) # legend fontsize 

plt.subplot(211)
plt.title('BPIC 2015_1 Continuous evaluation progress bin within prefix length 45')
plt.ylabel('Accuracy')
plt.xlabel('Progress bin')
axes.set_ylim([-0.05, 1.05])

# plt.xticks(rotation='45')


with open('./result/%s/htc_continuous_evaluation_rt50bin.pkl'%(dataset_label) ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'s',linewidth=4, color='green',linestyle='--',label = 'HTC',markersize=10)

with open('./result/%s/hatc_continuous_evaluation_rt50bin.pkl'%(dataset_label) ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'-*',linewidth=4, color='purple',linestyle='--',label = 'HATC',markersize=10)

with open('./result/%s/efdt_continuous_evaluation_rt50bin.pkl'%(dataset_label) ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'o',linewidth=4, color='#0047ab',linestyle=':',label = 'EFDT',markersize=10)

# Experiment settings
dataset_list = ['bpic15','bpic17_streaming','artificial_concept_Index-base']
dataset_label = 'bpic15'
bin_n = 50

try:
    os.makedirs('./img/%s'%(dataset_label))
except:
    pass


plt.subplot(212)
plt.title('BPIC 2015_1 Continuous evaluation progress bin within prefix length 13')
plt.ylabel('Accuracy')
plt.xlabel('Progress bin')
# plt.xticks(rotation='45')

axes.set_ylim([-0.05, 1.05])

with open('./result/%s/htc_continuous_evaluation_rt50bin13.pkl'%(dataset_label) ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'s',linewidth=4, color='green',linestyle='--',label = 'HTC',markersize=10)

with open('./result/%s/hatc_continuous_evaluation_rt50bin13.pkl'%(dataset_label) ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'-*',linewidth=4, color='purple',linestyle='--',label = 'HATC',markersize=10)

with open('./result/%s/efdt_continuous_evaluation_rt50bin13.pkl'%(dataset_label) ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'o',linewidth=4, color='#0047ab',linestyle=':',label = 'EFDT',markersize=10)
plt.tight_layout()
plt.legend()
plt.show()

# %%
# Experiment settings
dataset_list = ['bpic15','bpic17_streaming','artificial_concept_Index-base']
dataset_label = 'bpic17_streaming'
bin_n = 50

try:
    os.makedirs('./img/%s'%(dataset_label))
except:
    pass


plt.figure(figsize=(16, 20))

plt.rc('axes', titlesize=18) # fontsize of the axes title 
plt.rc('axes', labelsize=18) # fontsize of the x and y labels 
plt.rc('xtick', labelsize=15) # fontsize of the tick labels 
plt.rc('ytick', labelsize=15) # fontsize of the tick labels 
plt.rc('legend', fontsize=14) # legend fontsize 

plt.subplot(311)

plt.title('BPIC 2017 Continuous evaluation accuracy by prefix length')
plt.ylabel('Accuracy')
plt.xlabel('Prefix length')
# plt.xticks(rotation='45')
axes = plt.gca()
axes.set_ylim([-0.05, 1.05])


with open('./result/%s/htc_continuous_evaluation_plbin.pkl'%(dataset_label) ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'s',linewidth=4, color='green',linestyle='--',label = 'HTC',markersize=10)

with open('./result/%s/hatc_continuous_evaluation_plbin.pkl'%(dataset_label) ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'-*',linewidth=4, color='purple',linestyle='--',label = 'HATC',markersize=10)

with open('./result/%s/efdt_continuous_evaluation_plbin.pkl'%(dataset_label) ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'o',linewidth=4, color='#0047ab',linestyle=':',label = 'EFDT',markersize=10)
plt.legend(loc='upper left')

plt.subplot(312)

plt.title('BPIC 2017 Continuous evaluation accuracy by progress bin')
plt.ylabel('Accuracy')
plt.xlabel('Progress bin')
axes.set_ylim([-0.05, 1.05])

# plt.xticks(rotation='45')

with open('./result/%s/htc_continuous_evaluation_rt50bin.pkl'%(dataset_label) ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'s',linewidth=4, color='green',linestyle='--',label = 'HTC',markersize=10)

with open('./result/%s/hatc_continuous_evaluation_rt50bin.pkl'%(dataset_label) ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'-*',linewidth=4, color='purple',linestyle='--',label = 'HATC',markersize=10)

with open('./result/%s/efdt_continuous_evaluation_rt50bin.pkl'%(dataset_label) ,'rb') as f:
    data = pkl.load(f)
plt.plot(data[0],data[1],'o',linewidth=4, color='#0047ab',linestyle=':',label = 'EFDT',markersize=10)

xtick_label = ['%s'%((int(t)-1)*2) if (int(t)-1)*2 % 10 ==0 else ' ' for t in data[0]]
plt.xticks(ticks=data[0],labels=xtick_label)


plt.subplot(313)

for classifier in ['htc','hatc','efdt']:
    name = '%s %s window %s.pkl'%(dataset_label,classifier, window_size)
    with open('./result/%s/%s'%(dataset_label,name) ,'rb') as f:
        data =pkl.load(f)
    plt.plot(data,label = classifier)
plt.title('BPIC 2017 Window(%s)-evaluation average accuracy'%(window_size))
plt.legend()
plt.ylabel('Accuracy')
plt.xlabel('Finished cases')

with open('./result/%s/off_rf_acc.pkl'%(dataset_label),'rb') as f:
    rfdata = pkl.load(f)
with open('./result/%s/off_dt_acc.pkl'%(dataset_label),'rb') as f:
    dtdata = pkl.load(f)
plt.axhline(y=np.mean(rfdata[1]), color='purple', linestyle='-',label='Offline RF')
plt.axhline(y=np.mean(dtdata[1]), color='darkblue', linestyle='-',label='Offline DT')
plt.tight_layout()

plt.show()
